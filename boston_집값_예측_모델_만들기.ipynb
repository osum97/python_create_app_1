# %% [markdown]
# <a href="https://colab.research.google.com/github/osum97/python_create_app_1/blob/master/boston_%EC%A7%91%EA%B0%92_%EC%98%88%EC%B8%A1_%EB%AA%A8%EB%8D%B8_%EB%A7%8C%EB%93%A4%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **심화도전1**
# ### **boston house prices 데이터를 이용한 <span style="color:darkgreen"> AI 예측</span>문제**
# ---

# %% [markdown]
# #### Boston의 지역특성과 가격 데이터를 이용하여 , Boston 집값을 예측하는 AI문제입니다.
# #### AI코딩 단계에 따라 주어지는 문제를 읽고 답안을 작성하세요.
# #### (boston house prices 데이터 : sklearn 내장 연습용 데이터셋 사용)
#
#  - 데이터 : 회귀(수치)
#  - 모델 : 다중 회귀 분석 심화(선형, lidge, Lasso, elastic,), DeepLearning
#  - 주요 전처리 : 분석 Column 추가, 표준화(standardization), min-max Scaling
#  - 주요 학습 내용 : 다중 회귀 분석 심화 내용, 회귀 예측 모델 생성(input, output 처리, 손실함수 등)
# ---

# %% [markdown]
# **boston house prices 데이터 컬럼 설명**
# - TOWN
# - LON : 위도
# - LAT : 경도
# - CMEDV : 집주인이 실제 거주하는 집들의 주택가격 중앙값 (단위 천달러)
# - CRIM : 자치시(town)별 1인당 범죄율
# - ZN : 25,000 평방피트를 초과하는 거주지역의 비율
# - INDUS : 비소매상업지역이 점유하고 있는 토지의 비율
# - CHAS : 찰스강 근처는 1, 그렇지 않으면 0
# - NOX : 10ppm당 일산화질소 농도
# - RM : 주택 1가구당 평균 방의 개수
# - AGE : 1940년 이전에 건축된 소유주택의 비율
# - DIS : 5개의 보스턴 직업센터까지의 접근성 지수
# - RAD : 방사형 도로까지의 접근성 지수
# - TAX : 10,000달러 당 재산 새율
# - PTRATIO : 자치시(town)별 학생/교사 비율
# - B : 1000(Bk-0.63)^2, Bk는 자치시별 흑인의 비율
# - LSTAT : 값 (단위 $1,000)'

# %% [markdown]
# <br>
# <br>
# <br>

# %% [markdown]
# ### **Q1. Pandas를 pd로 alias하여 사용할 수 있도록 불러오는 코드를 작성하고 실행하시기 바랍니다.**
# ---

# %%
# 여기에 답안코드를 작성하세요

import pandas as pd

# %% [markdown]
# ### **Q2. Numpy를 np로 alias하여 사용할 수 있도록 불러오는 코드를 작성하고 실행하시기 바랍니다.**
# ---

# %%
# 여기에 답안코드를 작성하세요

import numpy as np

# %% [markdown]
# ### **Q3. 아래 가이드에 따라 BostonHousing3.csv 파일을 읽고 bhp 데이터프레임에 저장하세요.**
# * **
# - BostonHousing3.csv 파일 읽기
# - 데이터 프레임의 변수 명은 bhp 로 한다.
# ---

# %%
# 여기에 답안코드를 작성하세요

bhp = pd.read_csv('BostonHousing3.csv')
bhp
# Out:
#            TOWN      LON      LAT  CMEDV     CRIM    ZN  INDUS  CHAS    NOX  \
# 0        Nahant -70.9550  42.2550   24.0  0.00632  18.0   2.31     0  0.538
# 1    Swampscott -70.9500  42.2875   21.6  0.02731   0.0   7.07     0  0.469
# 2    Swampscott -70.9360  42.2830   34.7  0.02729   0.0   7.07     0  0.469
# 3    Marblehead -70.9280  42.2930   33.4  0.03237   0.0   2.18     0  0.458
# 4    Marblehead -70.9220  42.2980   36.2  0.06905   0.0   2.18     0  0.458
# ..          ...      ...      ...    ...      ...   ...    ...   ...    ...
# 501    Winthrop -70.9860  42.2312   22.4  0.06263   0.0  11.93     0  0.573
# 502    Winthrop -70.9910  42.2275   20.6  0.04527   0.0  11.93     0  0.573
# 503    Winthrop -70.9948  42.2260   23.9  0.06076   0.0  11.93     0  0.573
# 504    Winthrop -70.9875  42.2240   22.0  0.10959   0.0  11.93     0  0.573
# 505    Winthrop -70.9825  42.2210   19.0  0.04741   0.0  11.93     0  0.573
#
#         RM   AGE     DIS  RAD  TAX  PTRATIO       B  LSTAT
# 0    6.575  65.2  4.0900    1  296     15.3  396.90   4.98
# 1    6.421  78.9  4.9671    2  242     17.8  396.90   9.14
# 2    7.185  61.1  4.9671    2  242     17.8  392.83   4.03
# 3    6.998  45.8  6.0622    3  222     18.7  394.63   2.94
# 4    7.147  54.2  6.0622    3  222     18.7  396.90   5.33
# ..     ...   ...     ...  ...  ...      ...     ...    ...
# 501  6.593  69.1  2.4786    1  273     21.0  391.99   9.67
# 502  6.120  76.7  2.2875    1  273     21.0  396.90   9.08
# 503  6.976  91.0  2.1675    1  273     21.0  396.90   5.64
# 504  6.794  89.3  2.3889    1  273     21.0  393.45   6.48
# 505  6.030  80.8  2.5050    1  273     21.0  396.90   7.88
#
# [506 rows x 17 columns]

# %% [markdown]
# ### **Q4. 데이터 프레임 bhp에 대한 결측치 처리하세요.**
# * **
# - 결측치를 확인하세요.
# - 범주형 컬럼에 대해서는 최빈값으로 채우세요.
# - 연속형 컬럼에 대해서는 평균값으로 채우세요.
# - 100개 이상의 결측치가 있는 컬럼은 삭제하에요.
# - 결측치 처리 결과를 bhp_null 데이터프레임에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요

bhp_null = bhp.copy()

bhp_null.isnull().sum()
bhp_null['TOWN'] = bhp_null['TOWN'].fillna(bhp_null['TOWN'].mode()[0])
bhp_null['CRIM'] = bhp_null['CRIM'].fillna(bhp_null['CRIM'].mean())
bhp_null.drop('LAT', axis=1, inplace=True)
bhp_null.isnull().sum()
# Out:
# TOWN       0
# LON        0
# CMEDV      0
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# dtype: int64

# %% [markdown]
# ### **Q5. 데이터 프레임 bhp_null에 대해 가이드대로 시각화 하세요.**
# * **
# - seaborn 임포트하세요
# - seaborn의 histplot으로 그리세요.
#   - x : CMEDV 컬럼
# - 출력된 그래프를 보고 아래 보기 답안중에 틀린것을 변수05에 저장하세요(예, 변수05=5)
#     1. CMEDV 값이 30 일때, 제일 높은 카운트를 보인다.
#     2. 앞부분과 뒤부분의 분포가 적고 중간 20대 부근에 많은 분포를 보인다.
#     3. CMEDV 값이 50 근처에 20에 가까운 카운트를 보여주고 있다.
# ---

# %%
# 여기에 답안코드를 작성하세요

import seaborn as sns

sns.histplot(data=bhp_null, x='CMEDV', )

답안05=1

# %% [markdown]
# <br>

# %% [markdown]
# > **<span style="color:red">다음 문항을 풀기 전에 </span>아래 코드를 실행하시기 바랍니다.**
# >

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,7))

# %% [markdown]
# <br>

# %% [markdown]
# ### **Q6. 데이터 프레임 bhp_null에 대해 가이드대로 시각화 하세요.**
# * **
# - 숫자형 데이터에 대해서 heatmap 그래프를 그리세요.
#   - 데이터 : 숫자형 데이터의 상관관계
#   - heatmap 안에 상관관계 수치를 표시하세요.
#   - CMEDV 컬럼과 가장 높은 상관관계를 갖는 컬러명을 변수06 저장하세요.(예, 변수06='컬럼명')
# ---

# %%
# 여기에 답안코드를 작성하세요

plt.figure(figsize=(12,7))
corr = bhp_null.select_dtypes('number').corr()
sns.heatmap(corr, annot=True)

변수06='LSTAT'

# %% [markdown]
# ### **Q7. 아래 가이드대로 데이터프레임을 만들고 그룹화하세요.**
# * **
# - TOWN 컬럼 값중에서 'Cambridge', 'Boston Savin Hill', 'Lynn' 3개의 값으로 구성된 bhp_town 데이터 프레임을 만드세요.
# - TOWN 컬럼을 기준으로 그룹화하세요.
#   - 대상 데이터프레임 : bhp_town
#   - groupby 함수 활용하시고 각 컬럼의 평균을 출력하세요.
# - 그룹화 결과에서  TOWN이 'Boston Savin Hill' 일때, CMEDV 컬럼의 값을 변수07 저장하세요.(예, 변수07=1.123457)
# ---

# %%
# 여기에 답안코드를 작성하세요

bhp_town = bhp_null[ bhp_null['TOWN'].isin( [  'Cambridge', 'Boston Savin Hill', 'Lynn'   ])  ]
bhp_town.groupby('TOWN').mean()
변수07=13.234783

# %% [markdown]
# ### **Q8. 데이터 프레임 bhp_null에 대해 가이드대로 전처리하세요.**
# * **
# - 먼저, LON(위도) 컬럼을 삭제하세요.
# - 그다음, TOWN 컬럼에 대해서 원-핫-인코딩 수행하세요
#   - 대상 컬럼 : TOWN 컬럼
#   - 판다스 get_dummies 함수 활용
#   - 첫번째 가변수 삭제 처리 옵션 사용
# - 전처리 결과를 bhp_preset 변수에 저장하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요

bhp_preset = bhp_null.copy()
bhp_preset.drop('LON', axis=1, inplace=True)
bhp_preset = pd.get_dummies(data=bhp_preset, columns=['TOWN'], drop_first=True)
bhp_preset.head(3)
# Out:
#    CMEDV     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  ...  \
# 0   24.0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  ...
# 1   21.6  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  ...
# 2   34.7  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  ...
#
#    TOWN_Wayland  TOWN_Wellesley  TOWN_Wenham  TOWN_Weston  TOWN_Westwood  \
# 0         False           False        False        False          False
# 1         False           False        False        False          False
# 2         False           False        False        False          False
#
#    TOWN_Weymouth  TOWN_Wilmington  TOWN_Winchester  TOWN_Winthrop  TOWN_Woburn
# 0          False            False            False          False        False
# 1          False            False            False          False        False
# 2          False            False            False          False        False
#
# [3 rows x 105 columns]

# %% [markdown]
# ### **Q9. 데이터를 트레이닝셋 / 테스트셋으로 분할하시기 바랍니다.**
# * **
# - sklearn.model_selection 밑에 train_test_split 함수를 사용하세요.
# - y는 bhp_preset 데이터프레임의 'CMEDV'컬럼이고 x는 그 나머지 컬럼이다.
# - train : test = 8 : 2
# - 컬럼 CHAS 를 이용하여 stratify 하게 분할한다.
# - 변수명 규칙은 다음과 같다.
#     * x_train, y_train
#     * x_test, y_test
# - random state, seed 등은 2021로 설정한다.
#
# ---

# %%
# 여기에 답안코드를 작성하세요

x = bhp_preset.drop('CMEDV', axis=1)
y = bhp_preset['CMEDV']

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2021, stratify=bhp_preset['CHAS'])
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((404, 104), (102, 104), (404,), (102,))

# %% [markdown]
# ### **Q10. 데이터의 NOX와 RM은 민맥스(min-max) 스케일링 하시기 바랍니다.**
# * **
# - sklearn.preprocessing 밑의  MinMaxScaler 함수 사용하세요.
# - 트레이닝셋, 테스트셋에 대해서 스케일링 한다.
# ---

# %%
# 여기에 답안코드를 작성하세요

from sklearn.preprocessing import MinMaxScaler

mm_scaler = MinMaxScaler()
x_train[['NOX', 'RM']] = mm_scaler.fit_transform(x_train[['NOX', 'RM']] )
x_test[['NOX', 'RM']] = mm_scaler.transform(x_test[['NOX', 'RM']] )

# %% [markdown]
# ### **Q11. 데이터의 RAD와 B는 표준화(standardization) 스케일링 하시기 바랍니다.**
# * **
# - sklearn.preprocessing 밑의  StandardScaler 함수 사용하세요.
# - 트레이닝셋, 테스트셋에 대해서 스케일링 한다.
# ---

# %%
# 여기에 답안코드를 작성하세요

from sklearn.preprocessing import StandardScaler

st_scaler = StandardScaler()
x_train[['RAD', 'B']] = st_scaler.fit_transform(x_train[['RAD', 'B']] )
x_test[['RAD', 'B']] = st_scaler.transform(x_test[['RAD', 'B']] )

# %% [markdown]
# ### **Q12. 트레이닝 셋을 이용하여 선형회귀 모델을 학습시키시기 바랍니다.**
# * **
# - sklearn.linear_model 밑에 LinearRegression 함수 활용합니다.
# - LinearRegression 모델 이름을 lr로 정의합니다.
# - 트레이닝 데이터셋으로 학습을 진행합니다.
# ---

# %%
# 여기에 답안코드를 작성하세요

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### **Q13. 트레이닝 셋을 이용하여 RandomForest 모델을 학습시키시기 바랍니다.**
# * **
# - sklearn.ensemble 밑에 RandomForestRegressor 함수 활용합니다.
# - RandomForestRegressor 모델 이름을 rfr로 정의합니다.
# - 트레이닝 데이터셋으로 학습을 진행합니다.
# - rfr 모델 정의시, n_estimators : 100, max_depth : 10 설정하세요
# ---

# %%
# 여기에 답안코드를 작성하세요

from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 100, max_depth=10)
rfr.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=10)

# %% [markdown]
# ### **Q13. 테스트 셋을 이용하여 학습된 2개 모델의 성능을 출력하시기 바랍니다.**
# * **
# - 앞의 lr 모델과 rfr 모델로 테스트셋을 예측하여 결과값을 각각 lr_pred, rfr_pred에 저장하세요.
# - 평가를 위한 손실함수는 rmse, r2 를 이용하여 2개 모델에 대해서 rmse와 r2 성능을 출력하세요.
# - sklearn.metrics 밑에 mean_squared_error , r2_score 함수 활용하세요.
# ---

# %%
# 여기에 답안코드를 작성하세요
from sklearn.metrics import mean_squared_error , r2_score

lr_pred = lr.predict(x_test)
print(f'lr RMSE : { mean_squared_error(y_test, lr_pred)**0.5 }')
print(f'lr R2 : { r2_score(y_test, lr_pred) } ')


rfr_pred = rfr.predict(x_test)
print(f'rfr RMSE : { mean_squared_error(y_test, rfr_pred)**0.5 }')
print(f'rfr R2 : { r2_score(y_test, rfr_pred) } ')
# Out:
# lr RMSE : 554678971.1079019
# lr R2 : nan
# rfr RMSE : 2.58974218518029
# rfr R2 : 0.9510355566638606
# C:\Users\User\AppData\Local\Temp\ipykernel_9828\3883787192.py:6: RuntimeWarning: invalid value encountered in scalar power
#   print(f'lr R2 : { r2_score(y_test, lr_pred)**0.5 } ')

# %% [markdown]
# > **<span style="color:red">다음 문항을 풀기 전에 </span>아래 코드를 실행하시기 바랍니다.**
# >

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# ### **Q14. 아래 조건에 맞추어 뉴럴네트워크 모델을 학습시키시기 바랍니다.**
# * **
# - Tensorflow framework를 사용한다.
# - 히든레이어는 아래와 같은 규칙에 맞추어 구성합니다.
#     * 2개 이상의 hidden layer를 사용할 것
#     * FC layer뒤에는 batch normalization을 진행한다.
# - ModelCheckpoint 콜백으로 validation performance가 좋은 모델을 best_model.keras 파일로 저장한다.
# - 학습과정의 로그를 history에 선언하여 남긴다.
# - epochs는 200번을 진행한다.
# ---

# %%
# 여기에 답안코드를 작성하세요
keras.backend.clear_session()

model = Sequential()
model.add(Dense(32, activation='swish', input_shape=(x_train.shape[-1],)))
model.add(BatchNormalization())
model.add(Dense(32, activation='swish'))
model.add(BatchNormalization())
model.add(Dense(1))

model.compile(optimizer='adam',
              loss='mse'  )

mc = ModelCheckpoint('best_model.keras', monitor='val_loss', mode='min', save_best_only=True)
history = model.fit(x_train, y_train, epochs=200, batch_size=32,
                    verbose=1,validation_data=(x_test, y_test),callbacks=[mc])
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 1/200
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 610.7542 - val_loss: 464.9430
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 602.9753 - val_loss: 527.6411
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 588.7705 - val_loss: 538.4600
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 578.6085 - val_loss: 560.7166
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 555.6292 - val_loss: 543.8459
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 549.6061 - val_loss: 543.5737
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 599.7180 - val_loss: 528.5637
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 536.3669 - val_loss: 531.6313
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 520.0059 - val_loss: 585.6251
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 514.5556 - val_loss: 487.2730
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 487.3469 - val_loss: 536.0655
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 488.5822 - val_loss: 496.8668
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 489.5945 - val_loss: 543.7310
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 465.8506 - val_loss: 571.6671
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 448.1754 - val_loss: 533.3147
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 439.2795 - val_loss: 523.8126
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 429.9536 - val_loss: 602.2686
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 393.9328 - val_loss: 627.7329
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 392.3730 - val_loss: 592.9734
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 389.8234 - val_loss: 668.7455
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 365.4527 - val_loss: 529.6811
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 364.8846 - val_loss: 603.9876
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 322.5728 - val_loss: 635.1863
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 324.2277 - val_loss: 489.7784
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 314.8825 - val_loss: 371.7833
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 297.5399 - val_loss: 446.7374
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 273.4484 - val_loss: 374.9721
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 232.9619 - val_loss: 388.9121
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 237.1062 - val_loss: 322.5340
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 230.5642 - val_loss: 210.2319
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 199.8773 - val_loss: 142.6408
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 186.4624 - val_loss: 134.7079
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 180.0778 - val_loss: 73.2845
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 154.6595 - val_loss: 177.8886
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 148.6155 - val_loss: 77.6725
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 138.0286 - val_loss: 81.6479
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 123.9389 - val_loss: 70.8694
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 103.3164 - val_loss: 115.4213
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 91.3475 - val_loss: 49.5607
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 81.5497 - val_loss: 51.9934
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 79.3537 - val_loss: 37.8083
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 75.6119 - val_loss: 34.2896
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 68.0845 - val_loss: 35.1825
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 60.1666 - val_loss: 18.5899
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 42.8442 - val_loss: 28.8818
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55.4847 - val_loss: 21.7193
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 34.9701 - val_loss: 23.5167
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.7809 - val_loss: 15.3479
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.0964 - val_loss: 16.5859
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0008 - val_loss: 13.1914
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 20.8117 - val_loss: 14.3053
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.6156 - val_loss: 38.4049
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.1985 - val_loss: 14.9603
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.2154 - val_loss: 13.0737
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 24.3058 - val_loss: 13.0388
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.0889 - val_loss: 16.7456
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.8461 - val_loss: 13.5544
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.0769 - val_loss: 13.7828
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.8137 - val_loss: 76.7672
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 19.8852 - val_loss: 19.3575
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.0264 - val_loss: 23.9867
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.4513 - val_loss: 22.5177
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.5984 - val_loss: 14.8520
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.9874 - val_loss: 13.4574
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7622 - val_loss: 13.7079
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.7140 - val_loss: 28.1157
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.1269 - val_loss: 13.9009
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 14.4092 - val_loss: 11.5176
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9561 - val_loss: 16.2789
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.7760 - val_loss: 11.6918
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.3773 - val_loss: 12.0819
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.5290 - val_loss: 11.9094
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.2542 - val_loss: 14.1840
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.8195 - val_loss: 74.6357
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.2280 - val_loss: 48.8501
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.0412 - val_loss: 15.6229
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7597 - val_loss: 13.0816
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.3224 - val_loss: 43.6268
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.0201 - val_loss: 11.6733
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3491 - val_loss: 12.2250
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2532 - val_loss: 14.8469
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.4927 - val_loss: 23.3177
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.9981 - val_loss: 15.0987
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6881 - val_loss: 42.0668
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.5668 - val_loss: 10.8854
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.4790 - val_loss: 34.5449
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.7421 - val_loss: 13.4590
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1853 - val_loss: 41.1300
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.9391 - val_loss: 24.7509
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.6938 - val_loss: 14.8000
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6273 - val_loss: 15.0815
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7990 - val_loss: 20.0628
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.5177 - val_loss: 26.1515
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.4181 - val_loss: 11.1357
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.1199 - val_loss: 63.5188
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.8411 - val_loss: 13.7698
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1258 - val_loss: 11.0164
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1230 - val_loss: 12.7457
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.4195 - val_loss: 23.5658
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.1607 - val_loss: 42.2638
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.8046 - val_loss: 16.9094
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7608 - val_loss: 11.8648
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0288 - val_loss: 12.8350
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.1194 - val_loss: 11.7350
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8271 - val_loss: 10.8765
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.8709 - val_loss: 15.2894
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3480 - val_loss: 40.3365
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4142 - val_loss: 12.2501
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6343 - val_loss: 12.5828
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0943 - val_loss: 14.9948
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.2374 - val_loss: 27.5486
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.1229 - val_loss: 31.8989
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1824 - val_loss: 12.6078
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7811 - val_loss: 27.9687
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7957 - val_loss: 11.1955
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.7910 - val_loss: 16.1223
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6636 - val_loss: 20.8307
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 10.3869 - val_loss: 13.5432
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5224 - val_loss: 12.8609
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9699 - val_loss: 15.4197
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8243 - val_loss: 57.0538
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0519 - val_loss: 12.7077
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6198 - val_loss: 20.9864
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1228 - val_loss: 18.1410
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.2080 - val_loss: 17.9842
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7660 - val_loss: 11.3826
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6928 - val_loss: 11.5273
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1082 - val_loss: 15.0722
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1592 - val_loss: 14.5258
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5492 - val_loss: 21.5442
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.1113 - val_loss: 65.6622
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4440 - val_loss: 12.6040
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7105 - val_loss: 9.4315
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6877 - val_loss: 10.1084
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4516 - val_loss: 13.8554
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9050 - val_loss: 31.0163
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4674 - val_loss: 9.6377
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0357 - val_loss: 13.7213
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2475 - val_loss: 19.5599
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0182 - val_loss: 10.6342
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2721 - val_loss: 33.8740
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7653 - val_loss: 36.6558
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4840 - val_loss: 21.2364
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0527 - val_loss: 13.2633
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7096 - val_loss: 15.9143
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0822 - val_loss: 11.2456
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2801 - val_loss: 9.1190
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5267 - val_loss: 10.0194
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9580 - val_loss: 16.3189
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.8643 - val_loss: 10.7999
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4200 - val_loss: 28.8252
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4166 - val_loss: 11.5742
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4789 - val_loss: 10.8758
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8773 - val_loss: 13.3571
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2078 - val_loss: 9.9812
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4098 - val_loss: 8.1207
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8117 - val_loss: 16.8311
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2769 - val_loss: 11.7820
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7176 - val_loss: 26.2510
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4105 - val_loss: 26.5173
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1056 - val_loss: 9.0338
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9827 - val_loss: 22.5968
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1382 - val_loss: 15.7318
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8691 - val_loss: 15.7488
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2122 - val_loss: 17.3174
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7834 - val_loss: 14.4171
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6074 - val_loss: 16.2815
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2987 - val_loss: 14.0528
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3657 - val_loss: 26.5038
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0934 - val_loss: 8.8181
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4648 - val_loss: 17.9565
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7195 - val_loss: 12.4550
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1965 - val_loss: 13.3077
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1431 - val_loss: 12.2686
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.3626 - val_loss: 10.3133
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.0206 - val_loss: 29.9438
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5063 - val_loss: 8.4102
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7551 - val_loss: 7.6580
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5507 - val_loss: 13.5911
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5151 - val_loss: 36.9732
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5844 - val_loss: 21.0670
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8088 - val_loss: 10.7113
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2568 - val_loss: 9.1973
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1207 - val_loss: 10.7423
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7483 - val_loss: 8.6822
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1409 - val_loss: 8.9824
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12.8086 - val_loss: 11.6606
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6030 - val_loss: 9.7943
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.3405 - val_loss: 18.5199
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4919 - val_loss: 24.1712
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0367 - val_loss: 9.8246
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0138 - val_loss: 22.3353
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7002 - val_loss: 10.5091
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2446 - val_loss: 10.8452
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6525 - val_loss: 9.4774
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9692 - val_loss: 42.5185
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9702 - val_loss: 25.5288
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.8062 - val_loss: 15.0718
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 15.5069 - val_loss: 62.4198
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4258 - val_loss: 36.0923

# %% [markdown]
# ### **Q17. 다음 조건에 맞추어 뉴럴네트워크의 학습 로그를 시각화 하시기 바랍니다.**
# * **
# - epochs에 따른 loss의 변화를 시각화 한다.
# - loss와 val_loss를 둘다 시각화하고, 구별가능해야 한다.
# - 그래프의 타이틀은 'Loss'로 표시한다.
# - x축에는 'epochs'라고 표시하고 y축에는 'MSE'라고 표시한다.
# ---

# %%
# 여기에 답안코드를 작성하세요
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('MSE')
plt.legend(['loss', 'val_loss'])
plt.show()
